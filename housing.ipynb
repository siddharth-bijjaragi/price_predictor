# %% [markdown]
# <a href="https://colab.research.google.com/github/siddharth-bijjaragi/price_predictor/blob/main/housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
housing=pd.read_csv('/data2.csv')

# %%
housing.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRTIO  \
# 0  0.00632  18.0   2.31     0  0.538  7.147   65.2  4.0900    1  296    15.3
# 1  0.02731   0.0   7.07     0  0.469  6.430   78.9  4.9671    2  242    17.8
# 2  0.02729   0.0   7.07     0  0.469  6.012   61.1  4.9671    2  242    17.8
# 3  0.03237   0.0   2.18     0  0.458  6.172   45.8  6.0622    3  222    18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222    18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222    18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311    15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311    15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311    15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311    15.2
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2
# 5  394.12   5.21  28.7
# 6  395.60  12.43  22.9
# 7  396.90  19.15  27.1
# 8  386.63  29.93  16.5
# 9  386.71  17.10  18.9

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CRIM    506 non-null    float64
#  1   ZN      506 non-null    float64
#  2   INDUS   506 non-null    float64
#  3   CHAS    506 non-null    int64
#  4   NOX     506 non-null    float64
#  5   RM      506 non-null    float64
#  6   AGE     506 non-null    float64
#  7   DIS     506 non-null    float64
#  8   RAD     506 non-null    int64
#  9   TAX     506 non-null    int64
#  10  PTRTIO  506 non-null    float64
#  11  B       506 non-null    float64
#  12  LSTAT   506 non-null    float64
#  13  MEDV    506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.281832
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.701807
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.198500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.618750
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX      PTRTIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %% [markdown]
# ## Train-Test Splitting

# %%
# from sklearn.metrics import accuracy_score
# from sklearn.ensemble import HistGradientBoostingClassifier
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.model_selection import train_test_split
# x=housing.drop(['MEDV'],axis=1)
# y=housing['MEDV']
# train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2,random_state=100)
# estimated=RandomForestRegressor().fit(train_x,train_y)
# predict_y=estimated.predict(test_x)
# print(predict_y)
# print(accuracy_score(test_y,predict_y))

# %%
from sklearn.model_selection import train_test_split
train_set,test_set=train_test_split(housing,test_size=0.2,random_state=42)
print(f"Rows in train test : {len(train_set)} \nRows in test set : {len(test_set)}")
# Out:
# Rows in train test : 404
# Rows in test set : 102

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CRIM    506 non-null    float64
#  1   ZN      506 non-null    float64
#  2   INDUS   506 non-null    float64
#  3   CHAS    506 non-null    int64
#  4   NOX     506 non-null    float64
#  5   RM      506 non-null    float64
#  6   AGE     506 non-null    float64
#  7   DIS     506 non-null    float64
#  8   RAD     506 non-null    int64
#  9   TAX     506 non-null    int64
#  10  PTRTIO  506 non-null    float64
#  11  B       506 non-null    float64
#  12  LSTAT   506 non-null    float64
#  13  MEDV    506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# ## statified sampling

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)
for train_index , test_index in split.split(housing,housing['CHAS']):
    strat_train_set=housing.loc[train_index]
    strat_test_set=housing.loc[test_index]

# %%
strat_test_set['CHAS'].value_counts()
# Out:
# 0    95
# 1     7
# Name: CHAS, dtype: int64

# %%
strat_train_set['CHAS'].value_counts()
# Out:
# 0    376
# 1     28
# Name: CHAS, dtype: int64

# %%
housing = strat_train_set.copy()

# %% [markdown]
# ## correlations

# %%
corr_matrix=housing.corr()
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV      1.000000
# RM        0.672544
# B         0.361761
# ZN        0.339741
# DIS       0.240451
# CHAS      0.205066
# AGE      -0.364596
# RAD      -0.374693
# CRIM     -0.393715
# NOX      -0.422873
# TAX      -0.456657
# INDUS    -0.473516
# PTRTIO   -0.493534
# LSTAT    -0.740494
# Name: MEDV, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes=["MEDV","RM","ZN","LSTAT"]
scatter_matrix(housing[attributes],figsize=(12,8))
# Out:
# array([[<Axes: xlabel='MEDV', ylabel='MEDV'>,
#         <Axes: xlabel='RM', ylabel='MEDV'>,
#         <Axes: xlabel='ZN', ylabel='MEDV'>,
#         <Axes: xlabel='LSTAT', ylabel='MEDV'>],
#        [<Axes: xlabel='MEDV', ylabel='RM'>,
#         <Axes: xlabel='RM', ylabel='RM'>,
#         <Axes: xlabel='ZN', ylabel='RM'>,
#         <Axes: xlabel='LSTAT', ylabel='RM'>],
#        [<Axes: xlabel='MEDV', ylabel='ZN'>,
#         <Axes: xlabel='RM', ylabel='ZN'>,
#         <Axes: xlabel='ZN', ylabel='ZN'>,
#         <Axes: xlabel='LSTAT', ylabel='ZN'>],
#        [<Axes: xlabel='MEDV', ylabel='LSTAT'>,
#         <Axes: xlabel='RM', ylabel='LSTAT'>,
#         <Axes: xlabel='ZN', ylabel='LSTAT'>,
#         <Axes: xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %%
housing.plot(kind="scatter",x="RM",y="MEDV",alpha=0.9)
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %%
housing.plot(kind="scatter",x="LSTAT",y="MEDV",alpha=0.9)
# Out:
# <Axes: xlabel='LSTAT', ylabel='MEDV'>

# %%
housing
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRTIO  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315    16.4
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280    17.0
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666    20.2
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287    19.6
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287    19.6
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...     ...
# 155  3.53501   0.0  19.58     1  0.871  6.152  82.6  1.7455    5  403    14.7
# 423  7.05042   0.0  18.10     0  0.614  6.103  85.1  2.0218   24  666    20.2
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276    18.0
# 455  4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666    20.2
# 216  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121    5  276    16.4
#
#           B  LSTAT  MEDV
# 254  392.89   6.57  21.9
# 348  390.94   5.99  24.5
# 476  396.21  18.68  16.7
# 321  396.90   6.87  23.1
# 326  396.90   6.15  23.0
# ..      ...    ...   ...
# 155   88.01  15.02  15.6
# 423    2.52  23.29  13.4
# 98   393.53   3.57  43.8
# 455   50.92  18.13  14.1
# 216  392.80  13.51  23.3
#
# [404 rows x 14 columns]

# %%
housing.shape
# Out:
# (404, 14)

# %%
housing["TAXRM"]=housing['TAX'] / housing['RM']
housing["TAXRM"]
# Out:
# 254     51.571709
# 348     42.200452
# 476    102.714374
# 321     45.012547
# 326     45.468948
#           ...
# 155     65.507152
# 423    109.126659
# 98      35.294118
# 455    102.068966
# 216     46.875000
# Name: TAXRM, Length: 404, dtype: float64

# %%
housing.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRTIO  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315    16.4
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280    17.0
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666    20.2
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287    19.6
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287    19.6
#
#           B  LSTAT  MEDV       TAXRM
# 254  392.89   6.57  21.9   51.571709
# 348  390.94   5.99  24.5   42.200452
# 476  396.21  18.68  16.7  102.714374
# 321  396.90   6.87  23.1   45.012547
# 326  396.90   6.15  23.0   45.468948

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404 entries, 254 to 216
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CRIM    404 non-null    float64
#  1   ZN      404 non-null    float64
#  2   INDUS   404 non-null    float64
#  3   CHAS    404 non-null    int64
#  4   NOX     404 non-null    float64
#  5   RM      404 non-null    float64
#  6   AGE     404 non-null    float64
#  7   DIS     404 non-null    float64
#  8   RAD     404 non-null    int64
#  9   TAX     404 non-null    int64
#  10  PTRTIO  404 non-null    float64
#  11  B       404 non-null    float64
#  12  LSTAT   404 non-null    float64
#  13  MEDV    404 non-null    float64
#  14  TAXRM   404 non-null    float64
# dtypes: float64(12), int64(3)
# memory usage: 50.5 KB

# %%
corr_matrix=housing.corr()
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV      1.000000
# RM        0.672544
# B         0.361761
# ZN        0.339741
# DIS       0.240451
# CHAS      0.205066
# AGE      -0.364596
# RAD      -0.374693
# CRIM     -0.393715
# NOX      -0.422873
# TAX      -0.456657
# INDUS    -0.473516
# PTRTIO   -0.493534
# TAXRM    -0.524480
# LSTAT    -0.740494
# Name: MEDV, dtype: float64

# %%
import seaborn as sea
a=["MEDV","RM","ZN","LSTAT"]
sea.heatmap(housing[a],annot=True)
# Out:
# <Axes: >

# %%
housing = strat_train_set.drop("MEDV",axis=1)
housing_labels = strat_train_set["MEDV"].copy()

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.276376
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.711953
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.878750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.208500
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630000
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX      PTRTIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# std     28.258248    2.099057    8.731259  168.672623    2.129243   96.069235
# min      2.900000    1.129600    1.000000  187.000000   13.000000    0.320000
# 25%     44.850000    2.035975    4.000000  284.000000   17.400000  374.617500
# 50%     78.200000    3.122200    5.000000  337.000000   19.000000  390.955000
# 75%     94.100000    5.100400   24.000000  666.000000   20.200000  395.630000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT
# count  404.000000
# mean    12.791609
# std      7.235740
# min      1.730000
# 25%      6.847500
# 50%     11.570000
# 75%     17.102500
# max     36.980000

# %%
median = housing["RM"].median()
housing["RM"].fillna(median)
# Out:
# 254    6.108
# 348    6.635
# 476    6.484
# 321    6.376
# 326    6.312
#        ...
# 155    6.152
# 423    6.103
# 98     7.820
# 455    6.525
# 216    5.888
# Name: RM, Length: 404, dtype: float64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")
imputer.fit(housing)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([2.86735e-01, 0.00000e+00, 9.90000e+00, 0.00000e+00, 5.38000e-01,
#        6.20850e+00, 7.82000e+01, 3.12220e+00, 5.00000e+00, 3.37000e+02,
#        1.90000e+01, 3.90955e+02, 1.15700e+01])

# %%
X=imputer.transform(housing)
housing_tr = pd.DataFrame(X, columns=housing.columns)
housing_tr.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.276376
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.711953
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.878750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.208500
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630000
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX      PTRTIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# std     28.258248    2.099057    8.731259  168.672623    2.129243   96.069235
# min      2.900000    1.129600    1.000000  187.000000   13.000000    0.320000
# 25%     44.850000    2.035975    4.000000  284.000000   17.400000  374.617500
# 50%     78.200000    3.122200    5.000000  337.000000   19.000000  390.955000
# 75%     94.100000    5.100400   24.000000  666.000000   20.200000  395.630000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT
# count  404.000000
# mean    12.791609
# std      7.235740
# min      1.730000
# 25%      6.847500
# 50%     11.570000
# 75%     17.102500
# max     36.980000

# %%
import seaborn as sea
sea.barplot(x='RM',y='TAX',data=housing)
# Out:
# <Axes: xlabel='RM', ylabel='TAX'>

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline=Pipeline([('imputer',SimpleImputer(strategy="mean")),
                      # we can add any number of pipelines
                      ('std_scaler',StandardScaler()),
                      ])

# %%
housing_num_tr=my_pipeline.fit_transform(housing)

# %%
housing_num_tr
# Out:
# array([[-0.43942006,  3.12628155, -1.12165014, ..., -0.97491834,
#          0.41164221, -0.86091034],
#        [-0.44352175,  3.12628155, -1.35893781, ..., -0.69277865,
#          0.39131918, -0.94116739],
#        [ 0.15682292, -0.4898311 ,  0.98336806, ...,  0.81196637,
#          0.44624347,  0.81480158],
#        ...,
#        [-0.43525657, -0.4898311 , -1.23083158, ..., -0.22254583,
#          0.41831233, -1.27603303],
#        [ 0.14210728, -0.4898311 ,  0.98336806, ...,  0.81196637,
#         -3.15239177,  0.73869575],
#        [-0.43974024, -0.4898311 ,  0.37049623, ..., -0.97491834,
#          0.41070422,  0.09940681]])

# %%
housing_num_tr.shape
# Out:
# (404, 13)

# %% [markdown]
# ## Model Implementation

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
# model =LinearRegression()
# model=DecisionTreeRegressor()
model=RandomForestRegressor()
model.fit(housing_num_tr,housing_labels)
# Out:
# RandomForestRegressor()

# %%
some_data=housing.iloc[:5]
some_labels=housing_labels.iloc[:5]
prepared_data = my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([22.395, 25.164, 16.321, 23.347, 23.528])

# %%
list(some_labels)
# Out:
# [21.9, 24.5, 16.7, 23.1, 23.0]

# %% [markdown]
# ## Evaluating the Model

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
housing_predictions=model.predict(housing_num_tr)
mse=mean_squared_error(housing_labels,housing_predictions)
rmse=np.sqrt(mse)

# %%
rmse
print(f"The Minimum Error in the model is : {rmse}\nAccuracy of the model can be predicted as : {round(100-rmse)} % ")
# Out:
# The Minimum Error in the model is : 1.1428236407085628
# Accuracy of the model can be predicted as : 99 %

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
housing.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'CRIM'}>, <Axes: title={'center': 'ZN'}>,
#         <Axes: title={'center': 'INDUS'}>,
#         <Axes: title={'center': 'CHAS'}>],
#        [<Axes: title={'center': 'NOX'}>, <Axes: title={'center': 'RM'}>,
#         <Axes: title={'center': 'AGE'}>, <Axes: title={'center': 'DIS'}>],
#        [<Axes: title={'center': 'RAD'}>, <Axes: title={'center': 'TAX'}>,
#         <Axes: title={'center': 'PTRTIO'}>,
#         <Axes: title={'center': 'B'}>],
#        [<Axes: title={'center': 'LSTAT'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
plt.hist(housing['TAX'])
# Out:
# (array([ 43.,  71.,  89.,  24.,  65.,   0.,   0.,   0.,   0., 112.]),
#  array([187. , 239.4, 291.8, 344.2, 396.6, 449. , 501.4, 553.8, 606.2,
#         658.6, 711. ]),
#  <BarContainer object of 10 artists>)

# %%
sea.distplot(housing['RM'])
# Out:
# <ipython-input-43-225962a40458>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sea.distplot(housing['RM'])
# <Axes: xlabel='RM', ylabel='Density'>

# %%
sea.boxplot(housing['RM'])
# Out:
# <Axes: >

# %% [markdown]
# ## using better techniques

# %%
from sklearn.model_selection import cross_val_score
scores=cross_val_score(model,housing_num_tr,housing_labels,scoring="neg_mean_squared_error",cv=10)
rmse_scores=np.sqrt(-scores)
rmse_scores
# Out:
# array([2.91299394, 3.25578212, 4.4243013 , 2.54928893, 3.16663586,
#        2.58899056, 4.9453248 , 3.4622682 , 2.91046437, 3.31534171])

# %%
def print_scores(scores):
    print("Scores : ",scores)
    print("mean : ",scores.mean())
    print("Standard Deviation : ",scores.std())

# %%
print_scores(rmse_scores)
# Out:
# Scores :  [2.91299394 3.25578212 4.4243013  2.54928893 3.16663586 2.58899056
#  4.9453248  3.4622682  2.91046437 3.31534171]
# mean :  3.3531391775466313
# Standard Deviation :  0.7321086096384694

# %%
from joblib import dump, load
dump(model,'housing.joblib')
# Out:
# ['housing.joblib']

# %%
housing.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRTIO  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315    16.4
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280    17.0
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666    20.2
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287    19.6
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287    19.6
#
#           B  LSTAT
# 254  392.89   6.57
# 348  390.94   5.99
# 476  396.21  18.68
# 321  396.90   6.87
# 326  396.90   6.15

# %%
median = housing["RM"].median()
housing["RM"].fillna(median)
# Out:
# 254    6.108
# 348    6.635
# 476    6.484
# 321    6.376
# 326    6.312
#        ...
# 155    6.152
# 423    6.103
# 98     7.820
# 455    6.525
# 216    5.888
# Name: RM, Length: 404, dtype: float64

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404 entries, 254 to 216
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CRIM    404 non-null    float64
#  1   ZN      404 non-null    float64
#  2   INDUS   404 non-null    float64
#  3   CHAS    404 non-null    int64
#  4   NOX     404 non-null    float64
#  5   RM      404 non-null    float64
#  6   AGE     404 non-null    float64
#  7   DIS     404 non-null    float64
#  8   RAD     404 non-null    int64
#  9   TAX     404 non-null    int64
#  10  PTRTIO  404 non-null    float64
#  11  B       404 non-null    float64
#  12  LSTAT   404 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 60.4 KB

# %%
# from sklearn.metrics import accuracy_score
# from sklearn.ensemble import HistGradientBoostingClassifier
# estimated=DecisionTreeRegressor().fit(train_set,test_set)
# predict_y=estimated.predict(test_set)
# print(predict_y)
# print(accuracy_score(test_set,predict_y))

# %% [markdown]
# ## Testing the Model on test data

# %%
X_test=strat_test_set.drop("MEDV",axis=1)
y_test=strat_test_set["MEDV"].copy()
X_test_prepared=my_pipeline.fit_transform(X_test)
final_predictions=model.predict(X_test_prepared)
final_mse=mean_squared_error(y_test,final_predictions)
final_rmse=np.sqrt(final_mse)
print(final_predictions,list(y_test))
# Out:
# [24.417  9.547 25.528 21.122 17.257 14.55  19.556 14.732 32.753 42.062
#  19.226  9.332 24.569 27.62  20.107 12.62  31.187 14.994 23.352 18.016
#  18.81  15.301 16.306 21.665 18.909 31.274 16.68  32.309  9.856 34.107
#  24.112 21.004 23.058  8.604 20.285 12.175 41.411 23.614 24.838 44.528
#  23.554 25.574 19.756 21.656 15.581 32.652 44.794 19.921 18.547 22.699
#  21.588 15.122 19.761 14.774 24.732 32.493 40.959 28.825 18.143 20.727
#  47.373 10.271 18.888 23.834 14.883 38.918 19.321 17.004 17.376 33.588
#  26.661 22.977 20.425 23.59  35.709 13.479 15.821 20.291 21.146 21.524
#  22.289 21.96  13.872 22.935 20.665 21.659 14.338 21.102 22.418 23.39
#  18.1   26.678  8.729 24.826 16.809 30.736 19.745 31.139 13.652 26.603
#  18.434 18.122] [16.5, 10.2, 30.1, 23.0, 14.4, 15.6, 19.4, 14.1, 30.3, 35.2, 23.1, 13.8, 25.0, 27.9, 19.5, 12.3, 32.2, 13.5, 23.8, 21.7, 19.2, 19.5, 10.4, 23.2, 18.6, 28.5, 15.2, 32.0, 7.2, 34.6, 20.1, 20.6, 23.6, 13.1, 23.8, 12.7, 43.1, 24.7, 22.2, 44.0, 28.1, 31.0, 21.7, 23.4, 19.5, 33.1, 41.7, 18.7, 19.9, 20.6, 21.2, 13.6, 20.3, 17.8, 27.1, 31.5, 50.0, 29.1, 18.9, 20.4, 50.0, 7.2, 17.2, 36.2, 14.6, 33.2, 23.8, 19.9, 21.5, 37.3, 27.0, 22.0, 24.3, 19.8, 33.3, 7.0, 19.4, 20.9, 21.1, 20.4, 22.2, 11.9, 11.7, 21.6, 19.7, 23.0, 16.7, 21.7, 20.6, 23.3, 19.6, 28.0, 5.0, 24.4, 20.8, 24.8, 21.8, 23.6, 19.0, 25.0, 20.3, 21.5]

# %%
final_rmse
# Out:
# 3.4009310677299793

# %%
prepared_data[0]
# Out:
# array([-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
#        -0.23679239, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
#        -0.97491834,  0.41164221, -0.86091034])

# %%
import numpy as np
def predict_the_values(arr):
  model.predict(arr)

# %%
input=np.array([[-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
       -0.23481722, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
       -0.97491834,  0.41164221, -0.86091034]])
model.predict(input)
# Out:
# array([22.395])
